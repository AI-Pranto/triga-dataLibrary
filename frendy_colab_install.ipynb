# %%
! apt-get install csh libeigen3-dev -y
! wget -O - https://rpg.jaea.go.jp/download/frendy/frendy_20221104.tar.gz | tar xz -C /content
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# csh is already the newest version (20110502-5).
# libeigen3-dev is already the newest version (3.3.7-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# --2023-02-03 11:13:02--  https://rpg.jaea.go.jp/download/frendy/frendy_20221104.tar.gz
# Resolving rpg.jaea.go.jp (rpg.jaea.go.jp)... 107.154.79.132
# Connecting to rpg.jaea.go.jp (rpg.jaea.go.jp)|107.154.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97843362 (93M) [application/x-gzip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]  93.31M   965KB/s    in 2m 14s
#
# 2023-02-03 11:15:19 (716 KB/s) - written to stdout [97843362/97843362]

# %%
# %cd /content/frendy_20221104/frendy/
! ./compile_all.csh
# Out:
# /content/frendy_20221104/frendy
# Compile case name : main
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/CommentRemover.o_m -c ../CommonUtils/CommentRemover.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/DigitAdjuster.o_m -c ../CommonUtils/DigitAdjuster.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/ErrorManager.o_m -c ../CommonUtils/ErrorManager.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/FileCommentRemover.o_m -c ../CommonUtils/FileCommentRemover.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/StringUtils.o_m -c ../CommonUtils/StringUtils.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/TabAdjuster.o_m -c ../CommonUtils/TabAdjuster.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/TabInterpolator.o_m -c ../CommonUtils/TabInterpolator.cpp
# g++ -Wall -O2 -MMD -MP -I../ -std=c++11 -o ../CommonUtils/TimeUtils.o_m -c ../CommonUtils/TimeUtils.cpp
# ...

# %%
# %cd /content/
! git clone https://github.com/AI-Pranto/triga-dataLibrary.git
# %cd /content/triga-dataLibrary 
! rm -rf frendy.exe
! ln -s /content/frendy_20221104/frendy/main/frendy.exe .
# %cd lib/
! python download_library.py
# Out:
# /content
# Cloning into 'triga-dataLibrary'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 59 (delta 47), reused 56 (delta 47), pack-reused 0
# Unpacking objects: 100% (59/59), 5.20 KiB | 443.00 KiB/s, done.
# /content/triga-dataLibrary
# /content/triga-dataLibrary/lib

# %%
# %cd /content/triga-dataLibrary
! rm -rf frendy.exe
! ! ln -s /content/frendy_20221104/frendy/main/frendy.exe .
! ./run_frendy.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# ...
# =                   =
# =  --- CAUTION ---  =
# =                   =
# ...
#
#   <Class name>
#     ProbabilityTableCalculator
#
#   <Function name>
#     set_unreso_data()
#
#   <Warning message>
#     This material has no unresolved resonance data.
#     The probability table calculation is skipped.
#
# Total calculation time : 0.000366159 [s]
#
# *******************************************************************************************
#
# ****************************** Ace file generation ******************************
#
# FRENDY calculation date : 2023/02/03 13:12:22
#
# === Nuclear data information ===
#   Material No.       : 1625
#   Material Data (ZA) : 16032
#   Mass               : 31.6973
#   Temperature        : 296
#   Error              : 0.001
#
# === Set data information ===
#   Material data               : 1625
#   Temperature                 : 296
#   Cummulative angle option    : 1 (0:no, 1:yes)
# ...
